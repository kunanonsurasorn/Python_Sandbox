},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10074 entries, 0 to 10073
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   type of insurance company  10074 non-null  str
#  1   investment assets          10074 non-null  str
#  2   quarter                    10074 non-null  str
#  3   stock values               10074 non-null  str
# dtypes: str(4)
# memory usage: 314.9 KB

# %%
df.loc[df['stock values'] == '..']
# Out:
#          type of insurance company                    investment assets  \
# 1387      Life insurance companies  3.2.1   of which index-linked notes
# 1388      Life insurance companies  3.2.1   of which index-linked notes
# 1389      Life insurance companies  3.2.1   of which index-linked notes
# 1390      Life insurance companies  3.2.1   of which index-linked notes
# 1391      Life insurance companies  3.2.1   of which index-linked notes
# ...                            ...                                  ...
# 9857  Non-life insurance companies            10. Repurchase agreements
# 9858  Non-life insurance companies            10. Repurchase agreements
# 9859  Non-life insurance companies            10. Repurchase agreements
# 9860  Non-life insurance companies            10. Repurchase agreements
# 9861  Non-life insurance companies            10. Repurchase agreements
#
#      quarter stock values
# 1387  2007K3           ..
# 1388  2007K4           ..
# ...

# %%
df = df.replace(['..'],np.nan)

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
#          type of insurance company                    investment assets  \
# 1387      Life insurance companies  3.2.1   of which index-linked notes
# 1388      Life insurance companies  3.2.1   of which index-linked notes
# 1389      Life insurance companies  3.2.1   of which index-linked notes
# 1390      Life insurance companies  3.2.1   of which index-linked notes
# 1391      Life insurance companies  3.2.1   of which index-linked notes
# ...                            ...                                  ...
# 9857  Non-life insurance companies            10. Repurchase agreements
# 9858  Non-life insurance companies            10. Repurchase agreements
# 9859  Non-life insurance companies            10. Repurchase agreements
# 9860  Non-life insurance companies            10. Repurchase agreements
# 9861  Non-life insurance companies            10. Repurchase agreements
#
#      quarter stock values
# 1387  2007K3          NaN
# 1388  2007K4          NaN
# ...

# %%
df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
# Out:
#    type of insurance company            investment assets quarter stock values
# 0   Life insurance companies  1. Cash at bank and in hand  2007K3        29690
# 1   Life insurance companies  1. Cash at bank and in hand  2007K4        35045
# 2   Life insurance companies  1. Cash at bank and in hand  2008K1        42981
# 3   Life insurance companies  1. Cash at bank and in hand  2008K2        30477
# 4   Life insurance companies  1. Cash at bank and in hand  2008K3        35902
# ..                       ...                          ...     ...          ...
# 68  Life insurance companies  1. Cash at bank and in hand  2024K3       140187
# 69  Life insurance companies  1. Cash at bank and in hand  2024K4       107246
# 70  Life insurance companies  1. Cash at bank and in hand  2025K1       154165
# 71  Life insurance companies  1. Cash at bank and in hand  2025K2       139682
# 72  Life insurance companies  1. Cash at bank and in hand  2025K3       136042
#
# [73 rows x 4 columns]

# %%
df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
# Out:
#          type of insurance company            investment assets quarter  \
# 5037  Non-life insurance companies  1. Cash at bank and in hand  2007K3
# 5038  Non-life insurance companies  1. Cash at bank and in hand  2007K4
# 5039  Non-life insurance companies  1. Cash at bank and in hand  2008K1
# 5040  Non-life insurance companies  1. Cash at bank and in hand  2008K2
# 5041  Non-life insurance companies  1. Cash at bank and in hand  2008K3
# ...                            ...                          ...     ...
# 5105  Non-life insurance companies  1. Cash at bank and in hand  2024K3
# 5106  Non-life insurance companies  1. Cash at bank and in hand  2024K4
# 5107  Non-life insurance companies  1. Cash at bank and in hand  2025K1
# 5108  Non-life insurance companies  1. Cash at bank and in hand  2025K2
# 5109  Non-life insurance companies  1. Cash at bank and in hand  2025K3
#
#      stock values
# 5037        19811
# 5038        20868
# 5039        19449
# 5040        18184
# ...

# %%
df['investment assets'].unique()
# Out:
# <StringArray>
# [                          '1. Cash at bank and in hand',
#                                      '1.1 Swedish banks',
#                                      '1.2 Foreign banks',
#                            '2. Money market instruments',
#                                      '2.1 Issued in SEK',
#                         '2.2 Issued in foreign currency',
#                        '2.3 Issued by Swedish borrowers',
#                                       '2.3.1 Government',
#                       '2.3.2 Municipalities and regions',
#                                      '2.3.3 Banks (MFI)',
#                '2.3.4 Housing credit institutions (MFI)',
#                                        '2.3.5 Other MFI',
#                 '2.3.6 Financial institutions (non-MFI)',
#                        '2.3.7 Non-financial enterprises',
#                          '2.3.8 Other Swedish borrowers',
#                        '2.4 Issued by foreign borrowers',
# ...

# %%
df['quarter'].unique()
# Out:
# <StringArray>
# ['2007K3', '2007K4', '2008K1', '2008K2', '2008K3', '2008K4', '2009K1',
#  '2009K2', '2009K3', '2009K4', '2010K1', '2010K2', '2010K3', '2010K4',
#  '2011K1', '2011K2', '2011K3', '2011K4', '2012K1', '2012K2', '2012K3',
#  '2012K4', '2013K1', '2013K2', '2013K3', '2013K4', '2014K1', '2014K2',
#  '2014K3', '2014K4', '2015K1', '2015K2', '2015K3', '2015K4', '2016K1',
#  '2016K2', '2016K3', '2016K4', '2017K1', '2017K2', '2017K3', '2017K4',
#  '2018K1', '2018K2', '2018K3', '2018K4', '2019K1', '2019K2', '2019K3',
#  '2019K4', '2020K1', '2020K2', '2020K3', '2020K4', '2021K1', '2021K2',
#  '2021K3', '2021K4', '2022K1', '2022K2', '2022K3', '2022K4', '2023K1',
#  '2023K2', '2023K3', '2023K4', '2024K1', '2024K2', '2024K3', '2024K4',
#  '2025K1', '2025K2', '2025K3']
# Length: 73, dtype: str

# %%
df['type of insurance company'].unique()
# Out:
# <StringArray>
# ['Life insurance companies', 'Non-life insurance companies']
# Length: 2, dtype: str

# %%
df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
