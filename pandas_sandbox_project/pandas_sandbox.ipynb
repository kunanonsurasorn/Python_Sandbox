# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("000006NS_20260301-145543.csv")

# %%
df
# Out:
#           type of insurance company              investment assets quarter  \
# 0          Life insurance companies    1. Cash at bank and in hand  2007K3
# 1          Life insurance companies    1. Cash at bank and in hand  2007K4
# 2          Life insurance companies    1. Cash at bank and in hand  2008K1
# 3          Life insurance companies    1. Cash at bank and in hand  2008K2
# 4          Life insurance companies    1. Cash at bank and in hand  2008K3
# ...                             ...                            ...     ...
# 10069  Non-life insurance companies  12. Total capital investments  2024K3
# 10070  Non-life insurance companies  12. Total capital investments  2024K4
# 10071  Non-life insurance companies  12. Total capital investments  2025K1
# 10072  Non-life insurance companies  12. Total capital investments  2025K2
# 10073  Non-life insurance companies  12. Total capital investments  2025K3
#
# ...

# %%
df.head(10)
# Out:
#   type of insurance company            investment assets quarter  \
# 0  Life insurance companies  1. Cash at bank and in hand  2007K3
# 1  Life insurance companies  1. Cash at bank and in hand  2007K4
# 2  Life insurance companies  1. Cash at bank and in hand  2008K1
# 3  Life insurance companies  1. Cash at bank and in hand  2008K2
# 4  Life insurance companies  1. Cash at bank and in hand  2008K3
# 5  Life insurance companies  1. Cash at bank and in hand  2008K4
# 6  Life insurance companies  1. Cash at bank and in hand  2009K1
# 7  Life insurance companies  1. Cash at bank and in hand  2009K2
# 8  Life insurance companies  1. Cash at bank and in hand  2009K3
# 9  Life insurance companies  1. Cash at bank and in hand  2009K4
#
#   Investment assets of Swedish insurance companies, stock values, MSEK
# 0                                              29690
# 1                                              35045
# 2                                              42981
# ...

# %%
df.tail(10)
# Out:
#           type of insurance company              investment assets quarter  \
# 10064  Non-life insurance companies  12. Total capital investments  2023K2
# 10065  Non-life insurance companies  12. Total capital investments  2023K3
# 10066  Non-life insurance companies  12. Total capital investments  2023K4
# 10067  Non-life insurance companies  12. Total capital investments  2024K1
# 10068  Non-life insurance companies  12. Total capital investments  2024K2
# 10069  Non-life insurance companies  12. Total capital investments  2024K3
# 10070  Non-life insurance companies  12. Total capital investments  2024K4
# 10071  Non-life insurance companies  12. Total capital investments  2025K1
# 10072  Non-life insurance companies  12. Total capital investments  2025K2
# 10073  Non-life insurance companies  12. Total capital investments  2025K3
#
#       Investment assets of Swedish insurance companies, stock values, MSEK
# 10064                                             689461
# ...

# %%
df.dtypes
# Out:
# type of insurance company                                               str
# investment assets                                                       str
# quarter                                                                 str
# Investment assets of Swedish insurance companies, stock values, MSEK    str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10074 entries, 0 to 10073
# Data columns (total 4 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   type of insurance company                                             10074 non-null  str
#  1   investment assets                                                     10074 non-null  str
#  2   quarter                                                               10074 non-null  str
#  3   Investment assets of Swedish insurance companies, stock values, MSEK  10074 non-null  str
# dtypes: str(4)
# memory usage: 314.9 KB

# %%
df.rename(columns={'Investment assets of Swedish insurance companies, stock values, MSEK':'stock values'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10074 entries, 0 to 10073
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   type of insurance company  10074 non-null  str
#  1   investment assets          10074 non-null  str
#  2   quarter                    10074 non-null  str
#  3   stock values               10074 non-null  str
# dtypes: str(4)
# memory usage: 314.9 KB

# %%
df.loc[df['stock values'] == '..']
# Out:
#          type of insurance company                    investment assets  \
# 1387      Life insurance companies  3.2.1   of which index-linked notes
# 1388      Life insurance companies  3.2.1   of which index-linked notes
# 1389      Life insurance companies  3.2.1   of which index-linked notes
# 1390      Life insurance companies  3.2.1   of which index-linked notes
# 1391      Life insurance companies  3.2.1   of which index-linked notes
# ...                            ...                                  ...
# 9857  Non-life insurance companies            10. Repurchase agreements
# 9858  Non-life insurance companies            10. Repurchase agreements
# 9859  Non-life insurance companies            10. Repurchase agreements
# 9860  Non-life insurance companies            10. Repurchase agreements
# 9861  Non-life insurance companies            10. Repurchase agreements
#
#      quarter stock values
# 1387  2007K3           ..
# 1388  2007K4           ..
# ...

# %%
df = df.replace(['..'],np.nan)

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
#          type of insurance company                    investment assets  \
# 1387      Life insurance companies  3.2.1   of which index-linked notes
# 1388      Life insurance companies  3.2.1   of which index-linked notes
# 1389      Life insurance companies  3.2.1   of which index-linked notes
# 1390      Life insurance companies  3.2.1   of which index-linked notes
# 1391      Life insurance companies  3.2.1   of which index-linked notes
# ...                            ...                                  ...
# 9857  Non-life insurance companies            10. Repurchase agreements
# 9858  Non-life insurance companies            10. Repurchase agreements
# 9859  Non-life insurance companies            10. Repurchase agreements
# 9860  Non-life insurance companies            10. Repurchase agreements
# 9861  Non-life insurance companies            10. Repurchase agreements
#
#      quarter stock values
# 1387  2007K3          NaN
# 1388  2007K4          NaN
# ...

# %%
df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
# Out:
#    type of insurance company            investment assets quarter stock values
# 0   Life insurance companies  1. Cash at bank and in hand  2007K3        29690
# 1   Life insurance companies  1. Cash at bank and in hand  2007K4        35045
# 2   Life insurance companies  1. Cash at bank and in hand  2008K1        42981
# 3   Life insurance companies  1. Cash at bank and in hand  2008K2        30477
# 4   Life insurance companies  1. Cash at bank and in hand  2008K3        35902
# ..                       ...                          ...     ...          ...
# 68  Life insurance companies  1. Cash at bank and in hand  2024K3       140187
# 69  Life insurance companies  1. Cash at bank and in hand  2024K4       107246
# 70  Life insurance companies  1. Cash at bank and in hand  2025K1       154165
# 71  Life insurance companies  1. Cash at bank and in hand  2025K2       139682
# 72  Life insurance companies  1. Cash at bank and in hand  2025K3       136042
#
# [73 rows x 4 columns]

# %%
df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
# Out:
#          type of insurance company            investment assets quarter  \
# 5037  Non-life insurance companies  1. Cash at bank and in hand  2007K3
# 5038  Non-life insurance companies  1. Cash at bank and in hand  2007K4
# 5039  Non-life insurance companies  1. Cash at bank and in hand  2008K1
# 5040  Non-life insurance companies  1. Cash at bank and in hand  2008K2
# 5041  Non-life insurance companies  1. Cash at bank and in hand  2008K3
# ...                            ...                          ...     ...
# 5105  Non-life insurance companies  1. Cash at bank and in hand  2024K3
# 5106  Non-life insurance companies  1. Cash at bank and in hand  2024K4
# 5107  Non-life insurance companies  1. Cash at bank and in hand  2025K1
# 5108  Non-life insurance companies  1. Cash at bank and in hand  2025K2
# 5109  Non-life insurance companies  1. Cash at bank and in hand  2025K3
#
#      stock values
# 5037        19811
# 5038        20868
# 5039        19449
# 5040        18184
# ...

# %%
df['investment assets'].unique()
# Out:
# <StringArray>
# [                          '1. Cash at bank and in hand',
#                                      '1.1 Swedish banks',
#                                      '1.2 Foreign banks',
#                            '2. Money market instruments',
#                                      '2.1 Issued in SEK',
#                         '2.2 Issued in foreign currency',
#                        '2.3 Issued by Swedish borrowers',
#                                       '2.3.1 Government',
#                       '2.3.2 Municipalities and regions',
#                                      '2.3.3 Banks (MFI)',
#                '2.3.4 Housing credit institutions (MFI)',
#                                        '2.3.5 Other MFI',
#                 '2.3.6 Financial institutions (non-MFI)',
#                        '2.3.7 Non-financial enterprises',
#                          '2.3.8 Other Swedish borrowers',
#                        '2.4 Issued by foreign borrowers',
# ...

# %%
df['quarter'].unique()
# Out:
# <StringArray>
# ['2007K3', '2007K4', '2008K1', '2008K2', '2008K3', '2008K4', '2009K1',
#  '2009K2', '2009K3', '2009K4', '2010K1', '2010K2', '2010K3', '2010K4',
#  '2011K1', '2011K2', '2011K3', '2011K4', '2012K1', '2012K2', '2012K3',
#  '2012K4', '2013K1', '2013K2', '2013K3', '2013K4', '2014K1', '2014K2',
#  '2014K3', '2014K4', '2015K1', '2015K2', '2015K3', '2015K4', '2016K1',
#  '2016K2', '2016K3', '2016K4', '2017K1', '2017K2', '2017K3', '2017K4',
#  '2018K1', '2018K2', '2018K3', '2018K4', '2019K1', '2019K2', '2019K3',
#  '2019K4', '2020K1', '2020K2', '2020K3', '2020K4', '2021K1', '2021K2',
#  '2021K3', '2021K4', '2022K1', '2022K2', '2022K3', '2022K4', '2023K1',
#  '2023K2', '2023K3', '2023K4', '2024K1', '2024K2', '2024K3', '2024K4',
#  '2025K1', '2025K2', '2025K3']
# Length: 73, dtype: str

# %%
df = df.replace(['2007K3', '2007K4', '2008K1', '2008K2', '2008K3', '2008K4', '2009K1',
                 '2009K2', '2009K3', '2009K4', '2010K1', '2010K2', '2010K3', '2010K4',
                 '2011K1', '2011K2', '2011K3', '2011K4', '2012K1', '2012K2', '2012K3',
                 '2012K4', '2013K1', '2013K2', '2013K3', '2013K4', '2014K1', '2014K2',
                 '2014K3', '2014K4', '2015K1', '2015K2', '2015K3', '2015K4', '2016K1',
                 '2016K2', '2016K3', '2016K4', '2017K1', '2017K2', '2017K3', '2017K4',
                 '2018K1', '2018K2', '2018K3', '2018K4', '2019K1', '2019K2', '2019K3',
                 '2019K4', '2020K1', '2020K2', '2020K3', '2020K4', '2021K1', '2021K2',
                 '2021K3', '2021K4', '2022K1', '2022K2', '2022K3', '2022K4', '2023K1',
                 '2023K2', '2023K3', '2023K4', '2024K1', '2024K2', '2024K3', '2024K4',
                 '2025K1', '2025K2', '2025K3'],
                ['2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2009Q1',
                 '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2', '2010Q3', '2010Q4',
                 '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2', '2012Q3',
                 '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2',
                 '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
                 '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4',
                 '2018Q1', '2018Q2', '2018Q3', '2018Q4', '2019Q1', '2019Q2', '2019Q3',
                 '2019Q4', '2020Q1', '2020Q2', '2020Q3', '2020Q4', '2021Q1', '2021Q2',
                 '2021Q3', '2021Q4', '2022Q1', '2022Q2', '2022Q3', '2022Q4', '2023Q1',
                 '2023Q2', '2023Q3', '2023Q4', '2024Q1', '2024Q2', '2024Q3', '2024Q4',
                 '2025Q1', '2025Q2', '2025Q3'])

# %%
df = df.loc[df['quarter'].isin(['2008Q4','2009Q4','2010Q4','2011Q4',
                                '2012Q4','2013Q4','2014Q4','2015Q4',
                                '2016Q4','2017Q4','2018Q4','2019Q4',
                                '2020Q4','2021Q4','2022Q4','2023Q4',
                                '2024Q4'])]

# %%
df = df.set_index('quarter')

# %%
df['type of insurance company'].unique()
# Out:
# <StringArray>
# ['Life insurance companies', 'Non-life insurance companies']
# Length: 2, dtype: str

# %%
df['stock values'] = df['stock values'].astype('float64')

# %%
df
# Out:
#             type of insurance company              investment assets  \
# quarter
# 2008Q4       Life insurance companies    1. Cash at bank and in hand
# 2009Q4       Life insurance companies    1. Cash at bank and in hand
# 2010Q4       Life insurance companies    1. Cash at bank and in hand
# 2011Q4       Life insurance companies    1. Cash at bank and in hand
# 2012Q4       Life insurance companies    1. Cash at bank and in hand
# ...                               ...                            ...
# 2020Q4   Non-life insurance companies  12. Total capital investments
# 2021Q4   Non-life insurance companies  12. Total capital investments
# 2022Q4   Non-life insurance companies  12. Total capital investments
# 2023Q4   Non-life insurance companies  12. Total capital investments
# 2024Q4   Non-life insurance companies  12. Total capital investments
#
#          stock values
# quarter
# 2008Q4        59090.0
# 2009Q4        45730.0
# 2010Q4        49368.0
# 2011Q4        67569.0
# ...

# %%
life_insurance_cash_at_bank_and_in_hand = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
life_insurance_money_market_instruments = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '2. Money market instruments')]
life_insurance_bonds = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '3. Bonds')]
life_insurance_debentures_and_convertible_loans = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '4. Debentures and convertible loans')]
life_insurance_accrued_interest = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '5. Accrued interest')]
life_insurance_shares_and_participations = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '6. Shares and participations')]
life_insurance_loans = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '7. Loans')]
life_insurance_land_and_buildings = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '8. Land and buildings')]
life_insurance_derivatives = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '9. Derivatives')]
life_insurance_repurchase_agreements = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '10. Repurchase agreements')]
life_insurance_other_financial_investments = df[(df['type of insurance company'] == 'Life insurance companies') & (df['investment assets'] == '11. Other financial investments')]

# %%
non_life_insurance_cash_at_bank_and_in_hand = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '1. Cash at bank and in hand')]
non_life_insurance_money_market_instruments = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '2. Money market instruments')]
non_life_insurance_bonds = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '3. Bonds')]
non_life_insurance_debentures_and_convertible_loans = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '4. Debentures and convertible loans')]
non_life_insurance_accrued_interest = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '5. Accrued interest')]
non_life_insurance_shares_and_participations = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '6. Shares and participations')]
non_life_insurance_loans = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '7. Loans')]
non_life_insurance_land_and_buildings = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '8. Land and buildings')]
non_life_insurance_derivatives = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '9. Derivatives')]
non_life_insurance_repurchase_agreements = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '10. Repurchase agreements')]
non_life_insurance_other_financial_investments = df[(df['type of insurance company'] == 'Non-life insurance companies') & (df['investment assets'] == '11. Other financial investments')]

# %%
plt.plot(life_insurance_cash_at_bank_and_in_hand['stock values'],marker='o',linestyle='-',color='red',label='Life Insurance Companies')
plt.xlabel("Year-Quarter")
plt.ylabel("Stock Value (MSEK)")
plt.title("Q4 Stock Values of Cash at bank and in hand Chart")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.plot(non_life_insurance_cash_at_bank_and_in_hand['stock values'],marker='o',linestyle='-',color='blue',label='Non Life Insurance Companies')
plt.xlabel("Year-Quarter")
plt.ylabel("Stock Value (MSEK)")
plt.title("Q4 Stock Values of Cash at bank and in hand Chart")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.plot(life_insurance_cash_at_bank_and_in_hand['stock values'],marker='o',linestyle='-',color='red',label='Life Insurance Companies')
plt.plot(non_life_insurance_cash_at_bank_and_in_hand['stock values'],marker='o',linestyle='-',color='blue',label='Non Life Insurance Companies')
plt.xlabel("Year-Quarter")
plt.ylabel("Stock Value (MSEK)")
plt.title("Q4 Stock Values of Cash at bank and in hand Chart")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.bar(life_insurance_cash_at_bank_and_in_hand.index,life_insurance_cash_at_bank_and_in_hand['stock values'],color='r')
plt.bar(life_insurance_money_market_instruments.index,life_insurance_money_market_instruments['stock values'],bottom=life_insurance_cash_at_bank_and_in_hand['stock values'],color='b')
plt.bar(life_insurance_money_market_instruments.index,life_insurance_money_market_instruments['stock values'],bottom=life_insurance_cash_at_bank_and_in_hand['stock values'],color='b')
plt.xticks(rotation=45)
plt.show()
